# %%
import os

import project

# %%
def get_brick_fn(brick_id):
    return fn

def get_obj_row(brick_id, obj_id):
    return row

# %%
project.get_brick_fn

# %%
os.listdir('/scratch/jgreco/tractor/001')
# Out:
# ['legacysurvey_dr5_tractor_001.sha256sum',
#  'tractor-0010p292.fits',
#  'tractor-0010p295.fits',
#  'tractor-0010p297.fits',
#  'tractor-0010p300.fits',
#  'tractor-0011m002.fits',
#  'tractor-0011m005.fits',
#  'tractor-0011m007.fits',
#  'tractor-0011m010.fits',
#  'tractor-0011m012.fits',
#  'tractor-0011m015.fits',
#  'tractor-0011m017.fits',
#  'tractor-0011m020.fits',
#  'tractor-0011m022.fits',
#  'tractor-0011m025.fits',
#  'tractor-0011m027.fits',
#  'tractor-0011m030.fits',
#  'tractor-0011m032.fits',
#  'tractor-0011m035.fits',
#  'tractor-0011m037.fits',
#  'tractor-0011m040.fits',
#  'tractor-0011m042.fits',
#  'tractor-0011m045.fits',
#  'tractor-0011m047.fits',
#  'tractor-0011m050.fits',
#  'tractor-0011m052.fits',
#  'tractor-0011m055.fits',
#  'tractor-0011m057.fits',
#  'tractor-0011m060.fits',
#  'tractor-0011m062.fits',
#  'tractor-0011m065.fits',
#  'tractor-0011m067.fits',
#  'tractor-0011m070.fits',
#  'tractor-0011m072.fits',
#  'tractor-0011m075.fits',
# ...

# %%
fn = '/scratch/jgreco/tractor/001/tractor-0010p292.fits'

# %%
from astropy.table import Table, vstack

# %%
tab = Table.read(fn)
# Out:
# WARNING: UnitsWarning: '1/deg^2' did not parse as fits unit: Numeric factor not supported by FITS [astropy.units.core]
# WARNING: UnitsWarning: 'nanomaggy' did not parse as fits unit: At col 0, Unit 'nanomaggy' not supported by the FITS standard.  [astropy.units.core]
# WARNING: UnitsWarning: '1/nanomaggy^2' did not parse as fits unit: Numeric factor not supported by FITS [astropy.units.core]
# WARNING: UnitsWarning: '1/arcsec^2' did not parse as fits unit: Numeric factor not supported by FITS [astropy.units.core]

# %%
new_tab = Table()
for i in range(len(tab[:50])):
    new_tab = vstack([new_tab, tab[i]])
